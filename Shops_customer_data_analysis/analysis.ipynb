# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Customers.csv')
data
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
data.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
data.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
category = data.dtypes[data.dtypes=='object'].index
data[category].describe()
# Out:
#         Gender Profession
# count     2000       1965
# unique       2          9
# top     Female     Artist
# freq      1186        612

# %%
data[data['Profession'].isnull()]
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 79            80  Female   49              98000                      42
# 118          119  Female   51              84000                      43
# 219          220  Female   59              76000                      61
# 237          238    Male   95              36000                      35
# 437          438    Male   76             136259                      14
# 440          441  Female    0              57373                      29
# 498          499    Male   95             121725                       3
# 545          546  Female   89             107359                      26
# 601          602    Male   61             126370                      20
# 641          642    Male   66             121377                      19
# 665          666    Male   28             101414                      64
# 703          704    Male   22             114011                      40
# ...

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(22, 6))
sns.boxplot(x=data['Age'], ax=ax1)
sns.boxplot(x=data['Annual Income ($)'], ax=ax2)
sns.boxplot(x=data['Spending Score (1-100)'], ax=ax3)
# Out:
# <AxesSubplot:xlabel='Spending Score (1-100)'>

# %%
data[data['Work Experience']==data['Work Experience'].max()]
# Out:
#      CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 392         393    Male   21             119116                      30
# 405         406  Female   65             119889                      11
# 473         474    Male   20             130813                      92
# 566         567  Female   19             180331                      14
# 603         604  Female   91              69720                      78
#
#     Profession  Work Experience  Family Size
# 392     Artist               17            4
# 405     Artist               17            6
# 473     Artist               17            5
# 566     Artist               17            5
# 603     Lawyer               17            6

# %%
data[data['Age']-data['Work Experience']<18]
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 33            34    Male   18              62000                      92
# 39            40  Female   20              69000                      75
# 47            48  Female   27              71000                      47
# 61            62    Male   19              50000                      55
# 87            88  Female   22              55000                      55
# ...          ...     ...  ...                ...                     ...
# 1979        1980    Male    0             165321                      93
# 1980        1981  Female   10              86925                      76
# 1984        1985  Female    2             153622                      51
# 1986        1987  Female    4              68094                      61
# 1994        1995  Female   19              54121                      89
#
#       Profession  Work Experience  Family Size
# ...

# %%
data.loc[:,data.columns!='CustomerID'].hist(figsize=(20,14))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Annual Income ($)'}>],
#        [<AxesSubplot:title={'center':'Spending Score (1-100)'}>,
#         <AxesSubplot:title={'center':'Work Experience'}>],
#        [<AxesSubplot:title={'center':'Family Size'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
corr = data.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
