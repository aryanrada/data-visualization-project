# %%
import pandas as pd

# %%
data = pd.read_csv('Fifa_world_cup_matches.csv')
data
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %%
data.head()
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#           date     hour category  ...  penalties scored team1  \
# 0  20 NOV 2022  17 : 00  Group A  ...                       0
# ...

# %%
data.columns
# Out:
# Index(['team1', 'team2', 'possession team1', 'possession team2',
#        'possession in contest', 'number of goals team1',
#        'number of goals team2', 'date', 'hour', 'category',
#        'total attempts team1', 'total attempts team2', 'conceded team1',
#        'conceded team2', 'goal inside the penalty area team1',
#        'goal inside the penalty area team2',
#        'goal outside the penalty area team1',
#        'goal outside the penalty area team2', 'assists team1', 'assists team2',
#        'on target attempts team1', 'on target attempts team2',
#        'off target attempts team1', 'off target attempts team2',
#        'attempts inside the penalty area team1',
#        'attempts inside the penalty area  team2',
#        'attempts outside the penalty area  team1',
#        'attempts outside the penalty area  team2', 'left channel team1',
#        'left channel team2', 'left inside channel team1',
#        'left inside channel team2', 'central channel team1',
# ...

# %%
data[['team1', 'team2','number of goals team1','number of goals team2','goal inside the penalty area team1','goal inside the penalty area team2','goal outside the penalty area team1','goal outside the penalty area team2','yellow cards team1','yellow cards team2','red cards team1','red cards team2']]
# Out:
#             team1         team2  number of goals team1  number of goals team2  \
# 0           QATAR       ECUADOR                      0                      2
# 1         ENGLAND          IRAN                      6                      2
# 2         SENEGAL   NETHERLANDS                      0                      2
# 3   UNITED STATES         WALES                      1                      1
# 4       ARGENTINA  SAUDI ARABIA                      1                      2
# ..            ...           ...                    ...                    ...
# 59        ENGLAND        FRANCE                      1                      2
# 60      ARGENTINA       CROATIA                      3                      0
# 61         FRANCE       MOROCCO                      2                      0
# 62        CROATIA       MOROCCO                      2                      1
# 63      ARGENTINA        FRANCE                      3                      3
#
# ...

# %%
score1 = data.groupby('team1')['number of goals team1'].sum()
score1
# Out:
# team1
# ARGENTINA         11
# AUSTRALIA          1
# BELGIUM            1
# BRAZIL             7
# CAMEROON           4
# CANADA             1
# COSTA RICA         2
# CROATIA            7
# DENMARK            0
# ECUADOR            1
# ENGLAND           10
# FRANCE            11
# GERMANY            1
# GHANA              0
# IRAN               0
# JAPAN              3
# KOREA REPUBLIC     4
# MEXICO             0
# MOROCCO            1
# NETHERLANDS        8
# POLAND             2
# PORTUGAL          11
# QATAR              1
# SAUDI ARABIA       1
# SENEGAL            0
# SERBIA             2
# SPAIN              8
# SWITZERLAND        1
# TUNISIA            1
# UNITED STATES      1
# URUGUAY            0
# WALES              0
# Name: number of goals team1, dtype: int64

# %%
score2 = data.groupby('team2')['number of goals team2'].sum()
score2
# Out:
# team2
# ARGENTINA         4
# AUSTRALIA         3
# BELGIUM           0
# BRAZIL            1
# CAMEROON          0
# CANADA            1
# COSTA RICA        1
# CROATIA           1
# DENMARK           1
# ECUADOR           3
# ENGLAND           3
# FRANCE            5
# GERMANY           5
# GHANA             5
# IRAN              4
# JAPAN             2
# KOREA REPUBLIC    1
# MEXICO            2
# MOROCCO           5
# NETHERLANDS       2
# POLAND            1
# PORTUGAL          1
# QATAR             0
# SAUDI ARABIA      2
# SENEGAL           5
# SERBIA            3
# SPAIN             1
# SWITZERLAND       4
# TUNISIA           0
# UNITED STATES     2
# URUGUAY           2
# WALES             1
# Name: number of goals team2, dtype: int64

# %%
total_score = score1 + score2
total_score.sort_values(ascending=False)
# Out:
# team1
# FRANCE            16
# ARGENTINA         15
# ENGLAND           13
# PORTUGAL          12
# NETHERLANDS       10
# SPAIN              9
# BRAZIL             8
# CROATIA            8
# GERMANY            6
# MOROCCO            6
# GHANA              5
# KOREA REPUBLIC     5
# JAPAN              5
# SENEGAL            5
# SERBIA             5
# SWITZERLAND        5
# ECUADOR            4
# AUSTRALIA          4
# IRAN               4
# CAMEROON           4
# COSTA RICA         3
# UNITED STATES      3
# POLAND             3
# SAUDI ARABIA       3
# MEXICO             2
# CANADA             2
# URUGUAY            2
# DENMARK            1
# TUNISIA            1
# BELGIUM            1
# QATAR              1
# WALES              1
# dtype: int64

# %%
score_pn1 = data.groupby('team1')['goal inside the penalty area team1'].sum()
score_pn2 = data.groupby('team2')['goal inside the penalty area team2'].sum()

# %%
total_pn = score_pn1 + score_pn2
total_pn
# Out:
# team1
# ARGENTINA         14
# AUSTRALIA          3
# BELGIUM            1
# BRAZIL             8
# CAMEROON           4
# CANADA             1
# COSTA RICA         3
# CROATIA            7
# DENMARK            1
# ECUADOR            4
# ENGLAND           12
# FRANCE            15
# GERMANY            6
# GHANA              5
# IRAN               3
# JAPAN              4
# KOREA REPUBLIC     4
# MEXICO             1
# MOROCCO            5
# NETHERLANDS        9
# POLAND             3
# PORTUGAL          11
# QATAR              1
# SAUDI ARABIA       3
# SENEGAL            5
# SERBIA             4
# SPAIN              9
# SWITZERLAND        5
# TUNISIA            0
# UNITED STATES      3
# URUGUAY            2
# WALES              1
# dtype: int64

# %%
score_ou1 = data.groupby('team1')['goal outside the penalty area team1'].sum()
score_ou2 = data.groupby('team2')['goal outside the penalty area team2'].sum()

# %%
total_ou = score_ou1 + score_ou2
total_ou
# Out:
# team1
# ARGENTINA         1
# AUSTRALIA         0
# BELGIUM           0
# BRAZIL            0
# CAMEROON          0
# CANADA            0
# COSTA RICA        0
# CROATIA           1
# DENMARK           0
# ECUADOR           0
# ENGLAND           1
# FRANCE            1
# GERMANY           0
# GHANA             0
# IRAN              1
# JAPAN             1
# KOREA REPUBLIC    1
# MEXICO            1
# MOROCCO           1
# NETHERLANDS       1
# POLAND            0
# PORTUGAL          1
# QATAR             0
# SAUDI ARABIA      0
# SENEGAL           0
# SERBIA            1
# SPAIN             0
# SWITZERLAND       0
# TUNISIA           1
# UNITED STATES     0
# URUGUAY           0
# WALES             0
# dtype: int64

# %%
yellow1 = data.groupby('team1')['yellow cards team1'].sum()
yellow2 = data.groupby('team2')['yellow cards team2'].sum()
total_yellow = yellow1 + yellow2
total_yellow
# Out:
# team1
# ARGENTINA         16
# AUSTRALIA          7
# BELGIUM            5
# BRAZIL             6
# CAMEROON           8
# CANADA             8
# COSTA RICA         6
# CROATIA            8
# DENMARK            5
# ECUADOR            3
# ENGLAND            1
# FRANCE             8
# GERMANY            3
# GHANA              8
# IRAN               7
# JAPAN              6
# KOREA REPUBLIC     6
# MEXICO             7
# MOROCCO            9
# NETHERLANDS       12
# POLAND             7
# PORTUGAL           6
# QATAR              7
# SAUDI ARABIA      14
# SENEGAL            7
# SERBIA            12
# SPAIN              2
# SWITZERLAND        9
# TUNISIA            5
# UNITED STATES      5
# URUGUAY            8
# WALES              5
# dtype: int64

# %%
red1 = data.groupby('team1')['red cards team1'].sum()
red2 = data.groupby('team2')['red cards team2'].sum()
total_red = red1 + red2
total_red
# Out:
# team1
# ARGENTINA         0
# AUSTRALIA         0
# BELGIUM           0
# BRAZIL            0
# CAMEROON          1
# CANADA            0
# COSTA RICA        0
# CROATIA           0
# DENMARK           0
# ECUADOR           0
# ENGLAND           0
# FRANCE            0
# GERMANY           0
# GHANA             0
# IRAN              0
# JAPAN             0
# KOREA REPUBLIC    0
# MEXICO            0
# MOROCCO           1
# NETHERLANDS       1
# POLAND            0
# PORTUGAL          0
# QATAR             0
# SAUDI ARABIA      0
# SENEGAL           0
# SERBIA            0
# SPAIN             0
# SWITZERLAND       0
# TUNISIA           0
# UNITED STATES     0
# URUGUAY           0
# WALES             1
# dtype: int64

# %%
data['goals']=data['number of goals team1'] + data['number of goals team2']

# %%
data.pivot_table('goals',index='category',aggfunc='sum',fill_value=0,margins=True) #aggfunc='sum'
# Out:
#                           goals
# category
# Final                         6
# Group A                      15
# Group B                      16
# Group C                      12
# Group D                      11
# Group E                      22
# Group F                      11
# Group G                      16
# Group H                      17
# Play-off for third place      3
# Quarter-final                10
# Round of 16                  28
# Semi-final                    5
# All                         172
